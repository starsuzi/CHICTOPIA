# %%
import codecs
import io

# %%
s_file = open('./result_man.txt', 'r', encoding='utf-8')#codecs.open('./sample.txt', 'rb', 'utf-8')
s_filedata = s_file.read() 

s_filedata = s_filedata.replace("\\'", "'")
s_filedata = s_filedata.replace("'\\", "'")
s_filedata = s_filedata.replace('"', "'")
s_filedata = s_filedata.replace("]', b'[", "")

s_filedata = s_filedata.replace("post_id", '\n'+"post_id")
s_filedata = s_filedata.replace("title", '\n'+"title")
s_filedata = s_filedata.replace("photographer", '\n'+"photographer")
s_filedata = s_filedata.replace("lst_url", '\n'+"url")
s_filedata = s_filedata.replace("lst_size", '\n'+"size")
s_filedata = s_filedata.replace("lst_tag", '\n'+"tag")
s_filedata = s_filedata.replace("lst_item", '\n'+"item")

s_filedata = s_filedata.replace("'", '')
s_filedata = s_filedata.replace("[", '')
s_filedata = s_filedata.replace("]", '')

s_filedata = s_filedata.replace("http", '\n'+'http')
s_filedata = s_filedata.replace("jpg,", 'jpg')
s_filedata = s_filedata.replace("post_id", '\n'+'post_id')

s_filedata = s_filedata.replace("{", '')
s_filedata = s_filedata.replace("}", '')

# %%
print(s_filedata)
# Out:
# b
#
# post_id: 1202449,
# title: Septembrrr\xe2\x80\xa6 ,
# photographer: itsAndrei,
# url:
# http://images2.chictopia.com/photos/itsAndrei/6508128831/black-marelbo-shoes-black-zara-coat-black-h-m-pants.jpg
# http://images2.chictopia.com/photos/itsAndrei/3923061243/black-marelbo-shoes-black-zara-coat-black-h-m-pants.jpg
# http://images2.chictopia.com/photos/itsAndrei/7978848327/black-marelbo-shoes-black-zara-coat-black-h-m-pants.jpg
# size: (300, 450), (300, 450), (300, 450),
# tag: Chic, Everyday, Summer,
# item: black Marelbo shoes, black Zara coat, black H&M pants, ruby red emporio armani belt,
#
# post_id: 1183801,
# title: LAUNDROMAT,
# photographer: reyalfashion,
# url:
# http://images0.chictopia.com/photos/reyalfashion/8149191449/navy-eight-field-of-freedom-jeans-maroon-forever21-jacket.jpg
# http://images0.chictopia.com/photos/reyalfashion/11022673745/navy-eight-field-of-freedom-jeans-maroon-forever21-jacket.jpg
# ...

# %%
f_file = codecs.open('./result_man_changed.txt', 'w', 'utf-8')
f_file.write(s_filedata)

# %%
b'[

# %%
b"[

# %%
]', b'[ 935

# %%
2145
